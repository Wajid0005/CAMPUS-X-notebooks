# %% [markdown]
# <a href="https://colab.research.google.com/github/Wajid0005/CAMPUS-X-notebooks/blob/main/session_17_tasks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv"

# %% [markdown]
# ## Basic DataFrame
#
# Consider the following Python dictionary data and Python list labels:
#
# ```
# data = {'birds': ['Cranes', 'Cranes', 'plovers', 'spoonbills', 'spoonbills', 'Cranes', 'plovers', 'Cranes', 'spoonbills', 'spoonbills', 'Cranes'],
#         'age': [3.5, 4, 1.5, np.nan, 6, 3, 5.5, np.nan, 8, 4, 3.5], 'visits': [2, 4, 3, 4, 3, 4, 2, 2, 3, 2, 2],
#         'priority': ['yes', 'yes', 'no', np.nan, 'no', 'no', 'no', 'yes', 'no', 'no','yes']}
# ```
# ```
# labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j', 'k']
# ```

# %% [markdown]
# ###`Q-1:`
# i. Create a DataFrame birds from the above dictionary data which has the index labels.
#
# ii. Display basic information about the dataFrame.
#
# iii. Show Alternate rows of the dataframe.

# %%
data = {'birds': ['Cranes', 'Cranes', 'plovers', 'spoonbills', 'spoonbills', 'Cranes', 'plovers', 'Cranes', 'spoonbills', 'spoonbills', 'Cranes'],
        'age': [3.5, 4, 1.5, np.nan, 6, 3, 5.5, np.nan, 8, 4, 3.5], 'visits': [2, 4, 3, 4, 3, 4, 2, 2, 3, 2, 2],
        'priority': ['yes', 'yes', 'no', np.nan, 'no', 'no', 'no', 'yes', 'no', 'no','yes']}

# %%
import pandas as pd
import numpy as np

bird_df = pd.DataFrame(data)
bird_df
# Out:
#          birds  age  visits priority
# 0       Cranes  3.5       2      yes
# 1       Cranes  4.0       4      yes
# 2      plovers  1.5       3       no
# 3   spoonbills  NaN       4      NaN
# 4   spoonbills  6.0       3       no
# 5       Cranes  3.0       4       no
# 6      plovers  5.5       2       no
# 7       Cranes  NaN       2      yes
# 8   spoonbills  8.0       3       no
# 9   spoonbills  4.0       2       no
# 10      Cranes  3.5       2      yes

# %%
bird_df[::2]
# Out:
#          birds  age  visits priority
# 0       Cranes  3.5       2      yes
# 2      plovers  1.5       3       no
# 4   spoonbills  6.0       3       no
# 6      plovers  5.5       2       no
# 8   spoonbills  8.0       3       no
# 10      Cranes  3.5       2      yes

# %% [markdown]
# ###`Q-2:`
# i. Show only rows [1st, 3rd, 7th] from columns ['bird', 'age']
#
# ii. Select rows where the number of visits is less than 4.

# %%
bird_df[0:7:2]
# Out:
#         birds  age  visits priority
# 0      Cranes  3.5       2      yes
# 2     plovers  1.5       3       no
# 4  spoonbills  6.0       3       no
# 6     plovers  5.5       2       no

# %%
bird_df[bird_df['visits']< 4]
# Out:
#          birds  age  visits priority
# 0       Cranes  3.5       2      yes
# 2      plovers  1.5       3       no
# 4   spoonbills  6.0       3       no
# 6      plovers  5.5       2       no
# 7       Cranes  NaN       2      yes
# 8   spoonbills  8.0       3       no
# 9   spoonbills  4.0       2       no
# 10      Cranes  3.5       2      yes

# %% [markdown]
# ###`Q-3:`
# i. Select all rows with nan values in age and visits column.
#
# ii. Fill nan with respective series mode value.

# %%
bird_df[bird_df['age'].isna() | bird_df['visits'].isna()]
# Out:
#         birds  age  visits priority
# 3  spoonbills  NaN       4      NaN
# 7      Cranes  NaN       2      yes

# %%
bird_df.age.fillna(bird_df.age.mode()[0], inplace = True)
bird_df.visits.fillna(bird_df.visits.mode()[0], inplace = True)
bird_df
# Out:
# /tmp/ipython-input-3608418040.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   bird_df.visits.fillna(bird_df.visits.mode()[0], inplace = True)
#          birds  age  visits priority
# 0       Cranes  3.5       2      yes
# 1       Cranes  4.0       4      yes
# 2      plovers  1.5       3       no
# 3   spoonbills  3.5       4      NaN
# 4   spoonbills  6.0       3       no
# 5       Cranes  3.0       4       no
# 6      plovers  5.5       2       no
# 7       Cranes  3.5       2      yes
# ...

# %% [markdown]
# ###`Q-4`
# i. Find the total number of visits of the bird Cranes
#
# ii. Find the number of each type of birds in dataframe.
#
# iii. Print no of duplicate rows
#
# iv. Drop Duplicates rows and make this changes permanent. Show dataframe after changes.

# %%
#1
bird_df.visits[bird_df['birds']=='Cranes'].sum()

#2
bird_df['birds'].unique()
#3
bird_df.duplicated()
#4
bird_df.drop_duplicates(inplace = True)
bird_df
# Out:
#         birds  age  visits priority
# 0      Cranes  3.5       2      yes
# 1      Cranes  4.0       4      yes
# 2     plovers  1.5       3       no
# 3  spoonbills  3.5       4      NaN
# 4  spoonbills  6.0       3       no
# 5      Cranes  3.0       4       no
# 6     plovers  5.5       2       no
# 8  spoonbills  8.0       3       no
# 9  spoonbills  4.0       2       no

# %% [markdown]
# ##Question on IPL Data
#
# IPL Data Link :  https://drive.google.com/file/d/1yKVUuexl6lIKuFQy7uIPgDgXhJ0L4SIg/view?usp=share_link
#
# https://www.kaggle.com/datasets/vora1011/ipl-2008-to-2021-all-match-dataset?select=IPL_Matches_2008_2022.csv
#
# Download ipl matches 2008-2022 file.

# %% [markdown]
# ###`Q-5:` In IPL matches dataset some teams name has changed.
# You will have to consider them as same.
# ```
# 'Delhi Capitals' formerly as 'Delhi Daredevils'
# 'Punjab Kings' formerly as 'Kings XI Punjab'
# 'Rising Pune Supergiant' formerly as 'Rising Pune Supergiants'
# ```
# You need to make changes accordingly. Consider current name for each teams.
#
# Be careful Gujrat Titans and Gujrat Lions are different teams.

# %%
data = pd.read_csv("/content/IPL_Matches_2008_2022.csv")
data.sample(3)

changed_name = {'Delhi Capitals':'Delhi Daredevils' ,
'Punjab Kings':'Kings XI Punjab',
'Rising Pune Supergiant':'Rising Pune Supergiants'
}

data.replace(changed_name.keys(), changed_name.values(), inplace=True)
data.sample(3)
# Out:
#           ID    City        Date   Season MatchNumber                  Team1  \
# 905   336028  Mumbai  2008-05-21  2007/08          45         Mumbai Indians
# 229  1178400  Jaipur  2019-04-11     2019          25       Rajasthan Royals
# 244  1175365   Delhi  2019-03-30     2019          10  Kolkata Knight Riders
#
#                    Team2                   Venue           TossWinner  \
# 905      Kings XI Punjab        Wankhede Stadium       Mumbai Indians
# 229  Chennai Super Kings  Sawai Mansingh Stadium  Chennai Super Kings
# 244     Delhi Daredevils    Arun Jaitley Stadium     Delhi Daredevils
#
#     TossDecision SuperOver          WinningTeam      WonBy  Margin method  \
# 905        field         N      Kings XI Punjab       Runs     1.0    NaN
# 229        field         N  Chennai Super Kings    Wickets     4.0    NaN
# 244        field         Y     Delhi Daredevils  SuperOver     NaN    NaN
#
#     Player_of_Match                                       Team1Players  \
# ...

# %% [markdown]
# ###`Q-6` Write a code which can display the bar chart of top 5 teams who have played maximum number of matches in the IPL.
# >  Hint: Be careful the data is divided in 2 different cols(Team 1 and Team 2)

# %%
(data.Team1.value_counts() +data.Team2.value_counts()).sort_values(ascending=False).head(5).plot(kind = 'bar')
# Out:
# <Axes: >

# %% [markdown]
# ###`Q-7:` Player who got Most no. of player of the match award playing against Mumbai Indians.
# > Just for this question assume player of the match award is given to players from winning team. Although this is true in most of the cases.

# %%
m1 = (data.Team1 == 'Mumbai Indians') | (data.Team2 == 'Mumbai Indians')
m2 = data.WinningTeam != 'Mumbai Indians'
data[m1 & m2]['Player_of_Match'].value_counts()
# Out:
# Player_of_Match
# KL Rahul         4
# SK Raina         4
# SPD Smith        4
# JC Buttler       3
# KC Sangakkara    3
#                 ..
# PP Ojha          1
# Sohail Tanvir    1
# KD Karthik       1
# AC Gilchrist     1
# MV Boucher       1
# Name: count, Length: 68, dtype: int64

# %% [markdown]
# ###`Q-8:` Team1 vs Team2 Dashbord
# Create a function which will take two string(name of two teams) as input. Show win Loss record between them and player getting most player of the match award in matches between these two teams.
# ```
# team1_vs_team2('Kolkata Knight Riders','Chennai Super Kings')
# ```

# %%
m1 = (data.Team1 == 'Kolkata Knight Riders') | (data.Team2 == 'Kolkata knight Riders')
m2 = (data.Team1 == 'Chennai Super Kings') | (data.Team2 == 'Chennai Super Kings')
df1 = data[m1 & m2]
print(df1.WinningTeam.value_counts())
print(df1.Player_of_Match.value_counts())
# Out:
# WinningTeam
# Chennai Super Kings      9
# Kolkata Knight Riders    5
# Name: count, dtype: int64
# Player_of_Match
# RA Jadeja        2
# RD Gaikwad       1
# RA Tripathi      1
# Imran Tahir      1
# DL Chahar        1
# SW Billings      1
# AD Russell       1
# RV Uthappa       1
# MS Bisla         1
# MEK Hussey       1
# Iqbal Abdulla    1
# MS Dhoni         1
# M Ntini          1
# Name: count, dtype: int64

# %% [markdown]
# ### `Q-9:` Find out the top 7 cities where the matches of Kolkata Knight Riders are played frequently and plot the result as bar chart.
#
# *`.plot(kind = "bar")` can help you to plot the bar chart. Also you can learn more about this method from [here](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.html)*

# %%
data.City[data.Team1 == 'Kolkata Knight Riders'].value_counts().head(7).plot(kind = 'bar')
# Out:
# <Axes: xlabel='City'>

# %% [markdown]
# ### `Q-10:` Find out the average margin for the team Mumbai Indians for only the session 2011.

# %%
print("Average margin for the team Mumbai Indians for only the session 2011: ",data[((data.Team1 == 'Mumbai Indians') | (data.Team2 == 'Mumbai Indians')) & (data.Season == '2011')]['Margin'].mean())
# Out:
# average margin for the team Mumbai Indians for only the session 2011:  19.25
